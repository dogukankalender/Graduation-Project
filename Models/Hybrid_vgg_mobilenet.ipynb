# %%
import zipfile

path_to_zip_file = '/content/datadenekSON.zip'

directory_to_extract_to = '/content'

with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, Model, optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG19, MobileNet
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns

unfreeze_layers_vgg = 5
unfreeze_layers_mobilenet = 5

train_yes_path = '/content/datadenek2/beyin/veri/yes1'
train_no_path = '/content/datadenek2/beyin/veri/no1'

data = []
labels = []

for r, d, f in os.walk(train_yes_path):
    for file in f:
        if file.endswith('.jpg'):
            img_path = os.path.join(r, file)
            img = Image.open(img_path)
            img = img.resize((128, 128))
            img = np.array(img)
            if img.shape == (128, 128, 3):
                data.append(img)
                labels.append(0)

for r, d, f in os.walk(train_no_path):
    for file in f:
        if file.endswith('.jpg'):
            img_path = os.path.join(r, file)
            img = Image.open(img_path)
            img = img.resize((128, 128))
            img = np.array(img)
            if img.shape == (128, 128, 3):
                data.append(img)
                labels.append(1)

if len(data) == 0 or len(labels) == 0:
    raise ValueError("Data or labels are empty. Please check the data loading process.")

data = np.array(data)
labels = np.array(labels)

encoder = OneHotEncoder()
labels = encoder.fit_transform(labels.reshape(-1, 1)).toarray()

x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, shuffle=True, random_state=0)

x_train = x_train / 255.0
x_test = x_test / 255.0

train_datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest',
)

train_datagen.fit(x_train)

vgg19 = VGG19(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

for layer in vgg19.layers:
    layer.trainable = False

for layer in vgg19.layers[-unfreeze_layers_vgg:]:
    layer.trainable = True

mobilenet = MobileNet(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

for layer in mobilenet.layers:
    layer.trainable = False

for layer in mobilenet.layers[-unfreeze_layers_mobilenet:]:
    layer.trainable = True

vgg19_output = vgg19.output
mobilenet_output = mobilenet.output

vgg19_output = layers.GlobalAveragePooling2D()(vgg19_output)
mobilenet_output = layers.GlobalAveragePooling2D()(mobilenet_output)

merged = layers.concatenate([vgg19_output, mobilenet_output])

x = layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(merged)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(2, activation='sigmoid')(x)

model = Model(inputs=[vgg19.input, mobilenet.input], outputs=outputs)

model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])

checkpoint = ModelCheckpoint("best_model.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)

history = model.fit(
    train_datagen.flow([x_train, x_train], y_train, batch_size=32),
    steps_per_epoch=len(x_train) / 32,
    epochs=50,
    validation_data=([x_test, x_test], y_test),
    callbacks=[checkpoint, lr_scheduler, early_stopping]
)

evaluation_results = model.evaluate([x_test, x_test], y_test)
accuracy = evaluation_results[1]
print("Model Accuracy on Test Set: {:.2f}%".format(accuracy * 100))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

y_pred = model.predict([x_test, x_test])
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

precision = precision_score(y_true_classes, y_pred_classes)
recall = recall_score(y_true_classes, y_pred_classes)
f1 = f1_score(y_true_classes, y_pred_classes)

print("Precision: {:.2f}".format(precision))
print("Recall: {:.2f}".format(recall))
print("F1 Score: {:.2f}".format(f1))

cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Tumor', 'No Tumor'], yticklabels=['Tumor', 'No Tumor'])
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_128_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Epoch 1/50
# 65/64 [==============================] - ETA: 0s - loss: 7.4774 - accuracy: 0.8434
# Epoch 1: val_accuracy improved from -inf to 0.89342, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 64/64 [==============================] - 35s 351ms/step - loss: 7.4774 - accuracy: 0.8434 - val_loss: 6.6942 - val_accuracy: 0.8934 - lr: 1.0000e-04
# Epoch 2/50
# 65/64 [==============================] - ETA: 0s - loss: 6.0660 - accuracy: 0.9343
# Epoch 2: val_accuracy did not improve from 0.89342
# 64/64 [==============================] - 12s 186ms/step - loss: 6.0660 - accuracy: 0.9343 - val_loss: 5.6365 - val_accuracy: 0.8844 - lr: 1.0000e-04
# Epoch 3/50
# 65/64 [==============================] - ETA: 0s - loss: 4.9914 - accuracy: 0.9587
# Epoch 3: val_accuracy improved from 0.89342 to 0.97166, saving model to best_model.h5
# 64/64 [==============================] - 14s 219ms/step - loss: 4.9914 - accuracy: 0.9587 - val_loss: 4.5079 - val_accuracy: 0.9717 - lr: 1.0000e-04
# Epoch 4/50
# 65/64 [==============================] - ETA: 0s - loss: 4.1301 - accuracy: 0.9689
# Epoch 4: val_accuracy improved from 0.97166 to 0.97846, saving model to best_model.h5
# 64/64 [==============================] - 13s 200ms/step - loss: 4.1301 - accuracy: 0.9689 - val_loss: 3.7343 - val_accuracy: 0.9785 - lr: 1.0000e-04
# Epoch 5/50
# 65/64 [==============================] - ETA: 0s - loss: 3.4310 - accuracy: 0.9796
# Epoch 5: val_accuracy improved from 0.97846 to 0.97959, saving model to best_model.h5
# 64/64 [==============================] - 15s 238ms/step - loss: 3.4310 - accuracy: 0.9796 - val_loss: 3.1155 - val_accuracy: 0.9796 - lr: 1.0000e-04
# Epoch 6/50
# 65/64 [==============================] - ETA: 0s - loss: 2.8451 - accuracy: 0.9864
# Epoch 6: val_accuracy improved from 0.97959 to 0.98639, saving model to best_model.h5
# 64/64 [==============================] - 14s 222ms/step - loss: 2.8451 - accuracy: 0.9864 - val_loss: 2.5985 - val_accuracy: 0.9864 - lr: 1.0000e-04
# Epoch 7/50
# 65/64 [==============================] - ETA: 0s - loss: 2.3889 - accuracy: 0.9898
# Epoch 7: val_accuracy did not improve from 0.98639
# 64/64 [==============================] - 12s 186ms/step - loss: 2.3889 - accuracy: 0.9898 - val_loss: 2.2007 - val_accuracy: 0.9785 - lr: 1.0000e-04
# Epoch 8/50
# 65/64 [==============================] - ETA: 0s - loss: 2.0056 - accuracy: 0.9908
# Epoch 8: val_accuracy did not improve from 0.98639
# 64/64 [==============================] - 14s 210ms/step - loss: 2.0056 - accuracy: 0.9908 - val_loss: 1.8667 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 9/50
# 65/64 [==============================] - ETA: 0s - loss: 1.6898 - accuracy: 0.9951
# Epoch 9: val_accuracy did not improve from 0.98639
# 64/64 [==============================] - 13s 209ms/step - loss: 1.6898 - accuracy: 0.9951 - val_loss: 1.5881 - val_accuracy: 0.9728 - lr: 1.0000e-04
# Epoch 10/50
# 65/64 [==============================] - ETA: 0s - loss: 1.4324 - accuracy: 0.9942
# Epoch 10: val_accuracy did not improve from 0.98639
# 64/64 [==============================] - 13s 195ms/step - loss: 1.4324 - accuracy: 0.9942 - val_loss: 1.3971 - val_accuracy: 0.9580 - lr: 1.0000e-04
# Epoch 11/50
# 65/64 [==============================] - ETA: 0s - loss: 1.2284 - accuracy: 0.9932
# Epoch 11: val_accuracy did not improve from 0.98639
# 64/64 [==============================] - 14s 214ms/step - loss: 1.2284 - accuracy: 0.9932 - val_loss: 1.1682 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 12/50
# 65/64 [==============================] - ETA: 0s - loss: 1.0371 - accuracy: 0.9966
# Epoch 12: val_accuracy did not improve from 0.98639
# 64/64 [==============================] - 14s 214ms/step - loss: 1.0371 - accuracy: 0.9966 - val_loss: 0.9758 - val_accuracy: 0.9864 - lr: 1.0000e-04
# Epoch 13/50
# 65/64 [==============================] - ETA: 0s - loss: 0.8805 - accuracy: 0.9985
# Epoch 13: val_accuracy improved from 0.98639 to 0.98753, saving model to best_model.h5
# 64/64 [==============================] - 13s 198ms/step - loss: 0.8805 - accuracy: 0.9985 - val_loss: 0.8337 - val_accuracy: 0.9875 - lr: 1.0000e-04
# Epoch 14/50
# 65/64 [==============================] - ETA: 0s - loss: 0.7536 - accuracy: 0.9981
# Epoch 14: val_accuracy improved from 0.98753 to 0.99093, saving model to best_model.h5
# 64/64 [==============================] - 14s 214ms/step - loss: 0.7536 - accuracy: 0.9981 - val_loss: 0.7210 - val_accuracy: 0.9909 - lr: 1.0000e-04
# Epoch 15/50
# 65/64 [==============================] - ETA: 0s - loss: 0.6523 - accuracy: 0.9942
# Epoch 15: val_accuracy did not improve from 0.99093
# 64/64 [==============================] - 15s 233ms/step - loss: 0.6523 - accuracy: 0.9942 - val_loss: 0.6277 - val_accuracy: 0.9830 - lr: 1.0000e-04
# Epoch 16/50
# 65/64 [==============================] - ETA: 0s - loss: 0.5541 - accuracy: 0.9990
# Epoch 16: val_accuracy did not improve from 0.99093
# 64/64 [==============================] - 13s 208ms/step - loss: 0.5541 - accuracy: 0.9990 - val_loss: 0.5481 - val_accuracy: 0.9853 - lr: 1.0000e-04
# Epoch 17/50
# 65/64 [==============================] - ETA: 0s - loss: 0.4711 - accuracy: 0.9995
# Epoch 17: val_accuracy did not improve from 0.99093
# 64/64 [==============================] - 14s 216ms/step - loss: 0.4711 - accuracy: 0.9995 - val_loss: 0.4693 - val_accuracy: 0.9841 - lr: 1.0000e-04
# Epoch 18/50
# 65/64 [==============================] - ETA: 0s - loss: 0.4016 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.99093
# 64/64 [==============================] - 13s 209ms/step - loss: 0.4016 - accuracy: 1.0000 - val_loss: 0.3999 - val_accuracy: 0.9898 - lr: 1.0000e-04
# Epoch 19/50
# 65/64 [==============================] - ETA: 0s - loss: 0.3452 - accuracy: 0.9995
# Epoch 19: val_accuracy did not improve from 0.99093
# 64/64 [==============================] - 12s 188ms/step - loss: 0.3452 - accuracy: 0.9995 - val_loss: 0.3405 - val_accuracy: 0.9909 - lr: 1.0000e-04
# Epoch 20/50
# 65/64 [==============================] - ETA: 0s - loss: 0.2932 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.99093
# 64/64 [==============================] - 13s 196ms/step - loss: 0.2932 - accuracy: 1.0000 - val_loss: 0.3150 - val_accuracy: 0.9830 - lr: 1.0000e-04
# Epoch 21/50
# 65/64 [==============================] - ETA: 0s - loss: 0.2509 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.99093
# 64/64 [==============================] - 13s 208ms/step - loss: 0.2509 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9887 - lr: 1.0000e-04
# Epoch 22/50
# 65/64 [==============================] - ETA: 0s - loss: 0.2171 - accuracy: 0.9985
# Epoch 22: val_accuracy did not improve from 0.99093
# 64/64 [==============================] - 13s 208ms/step - loss: 0.2171 - accuracy: 0.9985 - val_loss: 0.2787 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 23/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9976
# Epoch 23: val_accuracy improved from 0.99093 to 0.99433, saving model to best_model.h5
# 64/64 [==============================] - 13s 196ms/step - loss: 0.1880 - accuracy: 0.9976 - val_loss: 0.1895 - val_accuracy: 0.9943 - lr: 1.0000e-04
# Epoch 24/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1578 - accuracy: 0.9995
# Epoch 24: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 200ms/step - loss: 0.1578 - accuracy: 0.9995 - val_loss: 0.1701 - val_accuracy: 0.9909 - lr: 1.0000e-04
# Epoch 25/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9995
# Epoch 25: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 210ms/step - loss: 0.1343 - accuracy: 0.9995 - val_loss: 0.1518 - val_accuracy: 0.9898 - lr: 1.0000e-04
# Epoch 26/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 207ms/step - loss: 0.1160 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9932 - lr: 1.0000e-04
# Epoch 27/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 0.9995
# Epoch 27: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 14s 218ms/step - loss: 0.0979 - accuracy: 0.9995 - val_loss: 0.1194 - val_accuracy: 0.9853 - lr: 1.0000e-04
# Epoch 28/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9995
# Epoch 28: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 207ms/step - loss: 0.0845 - accuracy: 0.9995 - val_loss: 0.1329 - val_accuracy: 0.9807 - lr: 1.0000e-04
# Epoch 29/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9995
# Epoch 29: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 12s 189ms/step - loss: 0.0729 - accuracy: 0.9995 - val_loss: 0.0960 - val_accuracy: 0.9909 - lr: 1.0000e-04
# Epoch 30/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 197ms/step - loss: 0.0614 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9864 - lr: 1.0000e-04
# Epoch 31/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9981
# Epoch 31: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 14s 214ms/step - loss: 0.0667 - accuracy: 0.9981 - val_loss: 0.0908 - val_accuracy: 0.9853 - lr: 1.0000e-04
# Epoch 32/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9990
# Epoch 32: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 205ms/step - loss: 0.0511 - accuracy: 0.9990 - val_loss: 0.0914 - val_accuracy: 0.9830 - lr: 1.0000e-04
# Epoch 33/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 12s 188ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9875 - lr: 1.0000e-04
# Epoch 34/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 194ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9864 - lr: 1.0000e-04
# Epoch 35/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9990
# Epoch 35: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 14s 210ms/step - loss: 0.0354 - accuracy: 0.9990 - val_loss: 0.0730 - val_accuracy: 0.9853 - lr: 1.0000e-04
# Epoch 36/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9903
# Epoch 36: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 197ms/step - loss: 0.0617 - accuracy: 0.9903 - val_loss: 0.0951 - val_accuracy: 0.9739 - lr: 1.0000e-04
# Epoch 37/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9981
# Epoch 37: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 12s 190ms/step - loss: 0.0392 - accuracy: 0.9981 - val_loss: 0.0680 - val_accuracy: 0.9853 - lr: 1.0000e-04
# Epoch 38/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9995
# Epoch 38: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 12s 184ms/step - loss: 0.0299 - accuracy: 0.9995 - val_loss: 0.0519 - val_accuracy: 0.9909 - lr: 1.0000e-04
# Epoch 39/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 11s 178ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9932 - lr: 1.0000e-04
# Epoch 40/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9995
# Epoch 40: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 197ms/step - loss: 0.0198 - accuracy: 0.9995 - val_loss: 0.0531 - val_accuracy: 0.9864 - lr: 1.0000e-04
# Epoch 41/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9995
# Epoch 41: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 12s 194ms/step - loss: 0.0207 - accuracy: 0.9995 - val_loss: 0.0977 - val_accuracy: 0.9705 - lr: 1.0000e-04
# Epoch 42/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9990
# Epoch 42: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 207ms/step - loss: 0.0185 - accuracy: 0.9990 - val_loss: 0.0405 - val_accuracy: 0.9932 - lr: 1.0000e-04
# Epoch 43/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 201ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9909 - lr: 1.0000e-04
# Epoch 44/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 203ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0512 - val_accuracy: 0.9887 - lr: 1.0000e-04
# Epoch 45/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9995
# Epoch 45: val_accuracy did not improve from 0.99433
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 64/64 [==============================] - 13s 207ms/step - loss: 0.0112 - accuracy: 0.9995 - val_loss: 0.0460 - val_accuracy: 0.9887 - lr: 1.0000e-04
# Epoch 46/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 14s 211ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9932 - lr: 1.0000e-05
# Epoch 47/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 12s 179ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9909 - lr: 1.0000e-05
# Epoch 48/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 11s 175ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9887 - lr: 1.0000e-05
# Epoch 49/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.99433
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 64/64 [==============================] - 13s 207ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9887 - lr: 1.0000e-05
# Epoch 50/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.99433
# 64/64 [==============================] - 13s 207ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9887 - lr: 1.0000e-06
# 28/28 [==============================] - 2s 66ms/step - loss: 0.0409 - accuracy: 0.9887
# Model Accuracy on Test Set: 98.87%
# 28/28 [==============================] - 2s 63ms/step
# Precision: 0.98
# Recall: 1.00
# F1 Score: 0.99
