# %%
import zipfile

path_to_zip_file = '/content/datadenek2.zip'

directory_to_extract_to = '/content'

with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, Model, optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet169
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns

train_yes_path = '/content/datadenek2/beyin/veri/yes1'
train_no_path = '/content/datadenek2/beyin/veri/no1'

data = []
labels = []

for r, d, f in os.walk(train_yes_path):
    for file in f:
        if file.endswith('.jpg'):
            img_path = os.path.join(r, file)
            img = Image.open(img_path)
            img = img.resize((128, 128))
            img = np.array(img)
            if img.shape == (128, 128, 3):
                data.append(img)
                labels.append(0)

for r, d, f in os.walk(train_no_path):
    for file in f:
        if file.endswith('.jpg'):
            img_path = os.path.join(r, file)
            img = Image.open(img_path)
            img = img.resize((128, 128))
            img = np.array(img)
            if img.shape == (128, 128, 3):
                data.append(img)
                labels.append(1)

if len(data) == 0 or len(labels) == 0:
    raise ValueError("Veriler veya etiketler boş. Lütfen veri yükleme sürecini kontrol edin.")

data = np.array(data)
labels = np.array(labels)

encoder = OneHotEncoder()
labels = encoder.fit_transform(labels.reshape(-1, 1)).toarray()

x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, shuffle=True, random_state=0)

x_train = x_train / 255.0
x_test = x_test / 255.0

train_datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest',
)

train_datagen.fit(x_train)

base_model = DenseNet169(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

for layer in base_model.layers:
    layer.trainable = False

for layer in base_model.layers[-20:]:
    layer.trainable = True

x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(2, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=outputs)

model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])

checkpoint = ModelCheckpoint("best_model.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)

history = model.fit(
    train_datagen.flow(x_train, y_train, batch_size=32),
    steps_per_epoch=len(x_train) / 32,
    epochs=50,
    validation_data=(x_test, y_test),
    callbacks=[checkpoint, lr_scheduler, early_stopping]
)

evaluation_results = model.evaluate(x_test, y_test)
accuracy = evaluation_results[1]
print("Test Setinde Model Doğruluğu: {:.2f}%".format(accuracy * 100))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Kayıp')
plt.ylabel('Kayıp')
plt.xlabel('Epoch')
plt.legend(['Eğitim', 'Doğrulama'], loc='upper right')
plt.show()

def names(number):
    if number == 0:
        return 'bir tümördür'
    else:
        return 'bir tümör değildir'

y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

precision = precision_score(y_true_classes, y_pred_classes)
recall = recall_score(y_true_classes, y_pred_classes)
f1 = f1_score(y_true_classes, y_pred_classes)

print("Kesinlik: {:.2f}".format(precision))
print("Hatırlama: {:.2f}".format(recall))
print("F1 Skoru: {:.2f}".format(f1))

cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['tümör bulunan', 'tümör bulunmayan'], yticklabels=['tümör bulunan', 'tümör bulunmayan'])
plt.ylabel('Gerçek Etiket')
plt.xlabel('Tahmin Edilen Etiket')
plt.title('Karışıklık Matrisi')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 0s 0us/step
# Epoch 1/50
# 65/64 [==============================] - ETA: 0s - loss: 3.5790 - accuracy: 0.8847
# Epoch 1: val_accuracy improved from -inf to 0.72222, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 64/64 [==============================] - 44s 371ms/step - loss: 3.5790 - accuracy: 0.8847 - val_loss: 2.6407 - val_accuracy: 0.7222 - lr: 0.0010
# Epoch 2/50
# 65/64 [==============================] - ETA: 0s - loss: 0.9999 - accuracy: 0.9363
# Epoch 2: val_accuracy improved from 0.72222 to 0.92063, saving model to best_model.h5
# 64/64 [==============================] - 13s 200ms/step - loss: 0.9999 - accuracy: 0.9363 - val_loss: 0.7751 - val_accuracy: 0.9206 - lr: 0.0010
# Epoch 3/50
# 65/64 [==============================] - ETA: 0s - loss: 0.5079 - accuracy: 0.9426
# Epoch 3: val_accuracy did not improve from 0.92063
# 64/64 [==============================] - 13s 200ms/step - loss: 0.5079 - accuracy: 0.9426 - val_loss: 0.7506 - val_accuracy: 0.8662 - lr: 0.0010
# Epoch 4/50
# 65/64 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.9601
# Epoch 4: val_accuracy improved from 0.92063 to 0.94671, saving model to best_model.h5
# 64/64 [==============================] - 13s 205ms/step - loss: 0.3175 - accuracy: 0.9601 - val_loss: 0.2969 - val_accuracy: 0.9467 - lr: 0.0010
# Epoch 5/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1977 - accuracy: 0.9713
# Epoch 5: val_accuracy improved from 0.94671 to 0.97052, saving model to best_model.h5
# 64/64 [==============================] - 14s 210ms/step - loss: 0.1977 - accuracy: 0.9713 - val_loss: 0.1699 - val_accuracy: 0.9705 - lr: 0.0010
# Epoch 6/50
# 65/64 [==============================] - ETA: 0s - loss: 0.2015 - accuracy: 0.9557
# Epoch 6: val_accuracy did not improve from 0.97052
# 64/64 [==============================] - 13s 197ms/step - loss: 0.2015 - accuracy: 0.9557 - val_loss: 0.2113 - val_accuracy: 0.9592 - lr: 0.0010
# Epoch 7/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.9728
# Epoch 7: val_accuracy did not improve from 0.97052
# 64/64 [==============================] - 12s 188ms/step - loss: 0.1496 - accuracy: 0.9728 - val_loss: 0.2084 - val_accuracy: 0.9512 - lr: 0.0010
# Epoch 8/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9830
# Epoch 8: val_accuracy did not improve from 0.97052
# 64/64 [==============================] - 12s 188ms/step - loss: 0.1042 - accuracy: 0.9830 - val_loss: 0.1402 - val_accuracy: 0.9660 - lr: 0.0010
# Epoch 9/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9747
# Epoch 9: val_accuracy improved from 0.97052 to 0.97279, saving model to best_model.h5
# 64/64 [==============================] - 14s 216ms/step - loss: 0.1065 - accuracy: 0.9747 - val_loss: 0.1264 - val_accuracy: 0.9728 - lr: 0.0010
# Epoch 10/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9718
# Epoch 10: val_accuracy did not improve from 0.97279
# 64/64 [==============================] - 12s 185ms/step - loss: 0.1128 - accuracy: 0.9718 - val_loss: 0.1682 - val_accuracy: 0.9649 - lr: 0.0010
# Epoch 11/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9805
# Epoch 11: val_accuracy did not improve from 0.97279
# 64/64 [==============================] - 12s 185ms/step - loss: 0.0984 - accuracy: 0.9805 - val_loss: 0.1344 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 12/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9801
# Epoch 12: val_accuracy did not improve from 0.97279
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 12s 185ms/step - loss: 0.0912 - accuracy: 0.9801 - val_loss: 0.1498 - val_accuracy: 0.9649 - lr: 0.0010
# Epoch 13/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9844
# Epoch 13: val_accuracy did not improve from 0.97279
# 64/64 [==============================] - 11s 173ms/step - loss: 0.0805 - accuracy: 0.9844 - val_loss: 0.1204 - val_accuracy: 0.9717 - lr: 1.0000e-04
# Epoch 14/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9912
# Epoch 14: val_accuracy improved from 0.97279 to 0.97619, saving model to best_model.h5
# 64/64 [==============================] - 13s 201ms/step - loss: 0.0602 - accuracy: 0.9912 - val_loss: 0.1083 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 15/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9961
# Epoch 15: val_accuracy improved from 0.97619 to 0.97732, saving model to best_model.h5
# 64/64 [==============================] - 13s 200ms/step - loss: 0.0513 - accuracy: 0.9961 - val_loss: 0.1074 - val_accuracy: 0.9773 - lr: 1.0000e-04
# Epoch 16/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9922
# Epoch 16: val_accuracy improved from 0.97732 to 0.98073, saving model to best_model.h5
# 64/64 [==============================] - 12s 193ms/step - loss: 0.0513 - accuracy: 0.9922 - val_loss: 0.1009 - val_accuracy: 0.9807 - lr: 1.0000e-04
# Epoch 17/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9912
# Epoch 17: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 12s 180ms/step - loss: 0.0571 - accuracy: 0.9912 - val_loss: 0.0979 - val_accuracy: 0.9796 - lr: 1.0000e-04
# Epoch 18/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9869
# Epoch 18: val_accuracy improved from 0.98073 to 0.98299, saving model to best_model.h5
# 64/64 [==============================] - 12s 185ms/step - loss: 0.0603 - accuracy: 0.9869 - val_loss: 0.0903 - val_accuracy: 0.9830 - lr: 1.0000e-04
# Epoch 19/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9946
# Epoch 19: val_accuracy did not improve from 0.98299
# 64/64 [==============================] - 11s 177ms/step - loss: 0.0445 - accuracy: 0.9946 - val_loss: 0.0892 - val_accuracy: 0.9819 - lr: 1.0000e-04
# Epoch 20/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9942
# Epoch 20: val_accuracy did not improve from 0.98299
# 64/64 [==============================] - 12s 181ms/step - loss: 0.0436 - accuracy: 0.9942 - val_loss: 0.0948 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 21/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9956
# Epoch 21: val_accuracy did not improve from 0.98299
# 64/64 [==============================] - 11s 178ms/step - loss: 0.0420 - accuracy: 0.9956 - val_loss: 0.0901 - val_accuracy: 0.9796 - lr: 1.0000e-04
# Epoch 22/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9946
# Epoch 22: val_accuracy did not improve from 0.98299
# 64/64 [==============================] - 12s 186ms/step - loss: 0.0423 - accuracy: 0.9946 - val_loss: 0.0862 - val_accuracy: 0.9807 - lr: 1.0000e-04
# Epoch 23/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 0.9942
# Epoch 23: val_accuracy did not improve from 0.98299
# 64/64 [==============================] - 12s 177ms/step - loss: 0.0402 - accuracy: 0.9942 - val_loss: 0.0895 - val_accuracy: 0.9751 - lr: 1.0000e-04
# Epoch 24/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9971
# Epoch 24: val_accuracy did not improve from 0.98299
# 64/64 [==============================] - 12s 184ms/step - loss: 0.0352 - accuracy: 0.9971 - val_loss: 0.0849 - val_accuracy: 0.9807 - lr: 1.0000e-04
# Epoch 25/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9976
# Epoch 25: val_accuracy did not improve from 0.98299
# 64/64 [==============================] - 11s 176ms/step - loss: 0.0323 - accuracy: 0.9976 - val_loss: 0.0856 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 26/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0318 - accuracy: 0.9966
# Epoch 26: val_accuracy did not improve from 0.98299
# 64/64 [==============================] - 11s 177ms/step - loss: 0.0318 - accuracy: 0.9966 - val_loss: 0.0857 - val_accuracy: 0.9796 - lr: 1.0000e-04
# Epoch 27/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9917
# Epoch 27: val_accuracy did not improve from 0.98299
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 64/64 [==============================] - 10s 159ms/step - loss: 0.0430 - accuracy: 0.9917 - val_loss: 0.0862 - val_accuracy: 0.9773 - lr: 1.0000e-04
# Epoch 28/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9981
# Epoch 28: val_accuracy did not improve from 0.98299
# 64/64 [==============================] - 12s 179ms/step - loss: 0.0309 - accuracy: 0.9981 - val_loss: 0.0856 - val_accuracy: 0.9773 - lr: 1.0000e-05
# Epoch 29/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9951
# Epoch 29: val_accuracy did not improve from 0.98299
# Restoring model weights from the end of the best epoch: 24.
# 64/64 [==============================] - 12s 184ms/step - loss: 0.0334 - accuracy: 0.9951 - val_loss: 0.0859 - val_accuracy: 0.9785 - lr: 1.0000e-05
# Epoch 29: early stopping
# 28/28 [==============================] - 1s 44ms/step - loss: 0.0849 - accuracy: 0.9807
# Test Setinde Model Doğruluğu: 98.07%
# 28/28 [==============================] - 5s 44ms/step
# Kesinlik: 0.98
# Hatırlama: 0.98
# F1 Skoru: 0.98

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, Model, optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet169
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns

# Eğitim verileri için yolları ayarlayın
train_yes_path = '/content/datadenek2/beyin/veri/yes1'
train_no_path = '/content/datadenek2/beyin/veri/no1'

# Görselleri yükleyin ve işleyin
data = []
labels = []

# 'Yes' (tümör var) görsellerini işleyin
for r, d, f in os.walk(train_yes_path):
    for file in f:
        if file.endswith('.jpg'):
            img_path = os.path.join(r, file)
            img = Image.open(img_path)
            img = img.resize((128, 128))
            img = np.array(img)
            if img.shape == (128, 128, 3):
                data.append(img)
                labels.append(0)  # 'yes' sınıfı

# 'No' (tümör yok) görsellerini işleyin
for r, d, f in os.walk(train_no_path):
    for file in f:
        if file.endswith('.jpg'):
            img_path = os.path.join(r, file)
            img = Image.open(img_path)
            img = img.resize((128, 128))
            img = np.array(img)
            if img.shape == (128, 128, 3):
                data.append(img)
                labels.append(1)  # 'no' sınıfı

# Veri ve etiketlerin doğru doldurulup doldurulmadığını kontrol edin
if len(data) == 0 or len(labels) == 0:
    raise ValueError("Veriler veya etiketler boş. Lütfen veri yükleme sürecini kontrol edin.")

data = np.array(data)
labels = np.array(labels)

# Etiketleri one-hot kodlayın
encoder = OneHotEncoder()
labels = encoder.fit_transform(labels.reshape(-1, 1)).toarray()

# Veriyi %70 eğitim ve %30 test olarak ayırın
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, shuffle=True, random_state=0)

# Görüntü verilerini normalize edin
x_train = x_train / 255.0
x_test = x_test / 255.0

# Veri artırma
train_datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,  # Dikey çevirme genellikle daha az kullanılır çünkü görüntülerin doğal yapısını bozabilir.
    fill_mode='nearest',
)

train_datagen.fit(x_train)

# DenseNet169 modelini tanımlayın
base_model = DenseNet169(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# Tüm katmanları dondurun
for layer in base_model.layers:
    layer.trainable = False

# Son 10 katmanı yeniden eğitilebilir yapın
for layer in base_model.layers[-20:]:
    layer.trainable = True

# DenseNet169 üzerine özel katmanlar ekleyin
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(2, activation='sigmoid')(x)

# Tam modeli oluşturun
model = Model(inputs=base_model.input, outputs=outputs)

# Modeli derleyin
model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])

# Model Checkpoint
checkpoint = ModelCheckpoint("best_model.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Öğrenme Oranı Azaltıcı
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)

# Erken Durdurma
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)

# Modeli eğitin
history = model.fit(
    train_datagen.flow(x_train, y_train, batch_size=32),
    steps_per_epoch=len(x_train) / 32,
    epochs=50,
    validation_data=(x_test, y_test),
    callbacks=[checkpoint, lr_scheduler, early_stopping]
)

# Modeli değerlendirin
evaluation_results = model.evaluate(x_test, y_test)
accuracy = evaluation_results[1]
print("Test Setinde Model Doğruluğu: {:.2f}%".format(accuracy * 100))

# Kayıp grafiği çizme
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Kayıp')
plt.ylabel('Kayıp')
plt.xlabel('Epoch')
plt.legend(['Eğitim', 'Doğrulama'], loc='upper right')
plt.show()

# Sınıf isimleri için yardımcı fonksiyon
def names(number):
    if number == 0:
        return 'bir tümördür'
    else:
        return 'bir tümör değildir'

# Kesinlik, Hatırlama ve F1 Skorunu Hesaplayın
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

precision = precision_score(y_true_classes, y_pred_classes)
recall = recall_score(y_true_classes, y_pred_classes)
f1 = f1_score(y_true_classes, y_pred_classes)

print("Kesinlik: {:.2f}".format(precision))
print("Hatırlama: {:.2f}".format(recall))
print("F1 Skoru: {:.2f}".format(f1))

# Karışıklık Matrisi
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['tümör bulunan', 'tümör bulunmayan'], yticklabels=['tümör bulunan', 'tümör bulunmayan'])
plt.ylabel('Gerçek Etiket')
plt.xlabel('Tahmin Edilen Etiket')
plt.title('Karışıklık Matrisi')
plt.show()
# Out:
# Epoch 1/50
# 65/64 [==============================] - ETA: 0s - loss: 7.4519 - accuracy: 0.7792
# Epoch 1: val_accuracy improved from -inf to 0.82653, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 64/64 [==============================] - 29s 265ms/step - loss: 7.4519 - accuracy: 0.7792 - val_loss: 6.4990 - val_accuracy: 0.8265 - lr: 1.0000e-04
# Epoch 2/50
# 65/64 [==============================] - ETA: 0s - loss: 5.6978 - accuracy: 0.9134
# Epoch 2: val_accuracy improved from 0.82653 to 0.92177, saving model to best_model.h5
# 64/64 [==============================] - 13s 193ms/step - loss: 5.6978 - accuracy: 0.9134 - val_loss: 5.0137 - val_accuracy: 0.9218 - lr: 1.0000e-04
# Epoch 3/50
# 65/64 [==============================] - ETA: 0s - loss: 4.4717 - accuracy: 0.9314
# Epoch 3: val_accuracy improved from 0.92177 to 0.95692, saving model to best_model.h5
# 64/64 [==============================] - 13s 196ms/step - loss: 4.4717 - accuracy: 0.9314 - val_loss: 3.9297 - val_accuracy: 0.9569 - lr: 1.0000e-04
# Epoch 4/50
# 65/64 [==============================] - ETA: 0s - loss: 3.5514 - accuracy: 0.9514
# Epoch 4: val_accuracy did not improve from 0.95692
# 64/64 [==============================] - 12s 182ms/step - loss: 3.5514 - accuracy: 0.9514 - val_loss: 3.1601 - val_accuracy: 0.9524 - lr: 1.0000e-04
# Epoch 5/50
# 65/64 [==============================] - ETA: 0s - loss: 2.8739 - accuracy: 0.9518
# Epoch 5: val_accuracy improved from 0.95692 to 0.96599, saving model to best_model.h5
# 64/64 [==============================] - 15s 229ms/step - loss: 2.8739 - accuracy: 0.9518 - val_loss: 2.5570 - val_accuracy: 0.9660 - lr: 1.0000e-04
# Epoch 6/50
# 65/64 [==============================] - ETA: 0s - loss: 2.3183 - accuracy: 0.9747
# Epoch 6: val_accuracy improved from 0.96599 to 0.96939, saving model to best_model.h5
# 64/64 [==============================] - 13s 195ms/step - loss: 2.3183 - accuracy: 0.9747 - val_loss: 2.1140 - val_accuracy: 0.9694 - lr: 1.0000e-04
# Epoch 7/50
# 65/64 [==============================] - ETA: 0s - loss: 1.9301 - accuracy: 0.9718
# Epoch 7: val_accuracy did not improve from 0.96939
# 64/64 [==============================] - 12s 180ms/step - loss: 1.9301 - accuracy: 0.9718 - val_loss: 1.7759 - val_accuracy: 0.9660 - lr: 1.0000e-04
# Epoch 8/50
# 65/64 [==============================] - ETA: 0s - loss: 1.6262 - accuracy: 0.9762
# Epoch 8: val_accuracy did not improve from 0.96939
# 64/64 [==============================] - 12s 181ms/step - loss: 1.6262 - accuracy: 0.9762 - val_loss: 1.5091 - val_accuracy: 0.9626 - lr: 1.0000e-04
# Epoch 9/50
# 65/64 [==============================] - ETA: 0s - loss: 1.3810 - accuracy: 0.9762
# Epoch 9: val_accuracy did not improve from 0.96939
# 64/64 [==============================] - 12s 183ms/step - loss: 1.3810 - accuracy: 0.9762 - val_loss: 1.3026 - val_accuracy: 0.9671 - lr: 1.0000e-04
# Epoch 10/50
# 65/64 [==============================] - ETA: 0s - loss: 1.2049 - accuracy: 0.9781
# Epoch 10: val_accuracy did not improve from 0.96939
# 64/64 [==============================] - 10s 160ms/step - loss: 1.2049 - accuracy: 0.9781 - val_loss: 1.1687 - val_accuracy: 0.9558 - lr: 1.0000e-04
# Epoch 11/50
# 65/64 [==============================] - ETA: 0s - loss: 1.0567 - accuracy: 0.9767
# Epoch 11: val_accuracy did not improve from 0.96939
# 64/64 [==============================] - 12s 182ms/step - loss: 1.0567 - accuracy: 0.9767 - val_loss: 1.0067 - val_accuracy: 0.9694 - lr: 1.0000e-04
# Epoch 12/50
# 65/64 [==============================] - ETA: 0s - loss: 0.9141 - accuracy: 0.9849
# Epoch 12: val_accuracy improved from 0.96939 to 0.97052, saving model to best_model.h5
# 64/64 [==============================] - 13s 196ms/step - loss: 0.9141 - accuracy: 0.9849 - val_loss: 0.8973 - val_accuracy: 0.9705 - lr: 1.0000e-04
# Epoch 13/50
# 65/64 [==============================] - ETA: 0s - loss: 0.8165 - accuracy: 0.9825
# Epoch 13: val_accuracy did not improve from 0.97052
# 64/64 [==============================] - 12s 181ms/step - loss: 0.8165 - accuracy: 0.9825 - val_loss: 0.8386 - val_accuracy: 0.9683 - lr: 1.0000e-04
# Epoch 14/50
# 65/64 [==============================] - ETA: 0s - loss: 0.7303 - accuracy: 0.9864
# Epoch 14: val_accuracy did not improve from 0.97052
# 64/64 [==============================] - 11s 175ms/step - loss: 0.7303 - accuracy: 0.9864 - val_loss: 0.7504 - val_accuracy: 0.9694 - lr: 1.0000e-04
# Epoch 15/50
# 65/64 [==============================] - ETA: 0s - loss: 0.6469 - accuracy: 0.9908
# Epoch 15: val_accuracy improved from 0.97052 to 0.97846, saving model to best_model.h5
# 64/64 [==============================] - 12s 184ms/step - loss: 0.6469 - accuracy: 0.9908 - val_loss: 0.6629 - val_accuracy: 0.9785 - lr: 1.0000e-04
# Epoch 16/50
# 65/64 [==============================] - ETA: 0s - loss: 0.5790 - accuracy: 0.9908
# Epoch 16: val_accuracy did not improve from 0.97846
# 64/64 [==============================] - 11s 162ms/step - loss: 0.5790 - accuracy: 0.9908 - val_loss: 0.5957 - val_accuracy: 0.9739 - lr: 1.0000e-04
# Epoch 17/50
# 65/64 [==============================] - ETA: 0s - loss: 0.5231 - accuracy: 0.9912
# Epoch 17: val_accuracy did not improve from 0.97846
# 64/64 [==============================] - 12s 183ms/step - loss: 0.5231 - accuracy: 0.9912 - val_loss: 0.5346 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 18/50
# 65/64 [==============================] - ETA: 0s - loss: 0.4764 - accuracy: 0.9888
# Epoch 18: val_accuracy did not improve from 0.97846
# 64/64 [==============================] - 12s 180ms/step - loss: 0.4764 - accuracy: 0.9888 - val_loss: 0.4905 - val_accuracy: 0.9785 - lr: 1.0000e-04
# Epoch 19/50
# 65/64 [==============================] - ETA: 0s - loss: 0.4314 - accuracy: 0.9888
# Epoch 19: val_accuracy did not improve from 0.97846
# 64/64 [==============================] - 12s 191ms/step - loss: 0.4314 - accuracy: 0.9888 - val_loss: 0.4590 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 20/50
# 65/64 [==============================] - ETA: 0s - loss: 0.3887 - accuracy: 0.9898
# Epoch 20: val_accuracy did not improve from 0.97846
# 64/64 [==============================] - 12s 178ms/step - loss: 0.3887 - accuracy: 0.9898 - val_loss: 0.4280 - val_accuracy: 0.9683 - lr: 1.0000e-04
# Epoch 21/50
# 65/64 [==============================] - ETA: 0s - loss: 0.3508 - accuracy: 0.9908
# Epoch 21: val_accuracy did not improve from 0.97846
# 64/64 [==============================] - 12s 183ms/step - loss: 0.3508 - accuracy: 0.9908 - val_loss: 0.4038 - val_accuracy: 0.9671 - lr: 1.0000e-04
# Epoch 22/50
# 65/64 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.9917
# Epoch 22: val_accuracy did not improve from 0.97846
# 64/64 [==============================] - 12s 182ms/step - loss: 0.3152 - accuracy: 0.9917 - val_loss: 0.3502 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 23/50
# 65/64 [==============================] - ETA: 0s - loss: 0.2926 - accuracy: 0.9903
# Epoch 23: val_accuracy did not improve from 0.97846
# 64/64 [==============================] - 11s 169ms/step - loss: 0.2926 - accuracy: 0.9903 - val_loss: 0.3271 - val_accuracy: 0.9705 - lr: 1.0000e-04
# Epoch 24/50
# 65/64 [==============================] - ETA: 0s - loss: 0.2685 - accuracy: 0.9883
# Epoch 24: val_accuracy improved from 0.97846 to 0.97959, saving model to best_model.h5
# 64/64 [==============================] - 13s 203ms/step - loss: 0.2685 - accuracy: 0.9883 - val_loss: 0.2977 - val_accuracy: 0.9796 - lr: 1.0000e-04
# Epoch 25/50
# 65/64 [==============================] - ETA: 0s - loss: 0.2298 - accuracy: 0.9951
# Epoch 25: val_accuracy did not improve from 0.97959
# 64/64 [==============================] - 12s 182ms/step - loss: 0.2298 - accuracy: 0.9951 - val_loss: 0.2719 - val_accuracy: 0.9796 - lr: 1.0000e-04
# Epoch 26/50
# 65/64 [==============================] - ETA: 0s - loss: 0.2095 - accuracy: 0.9966
# Epoch 26: val_accuracy did not improve from 0.97959
# 64/64 [==============================] - 11s 177ms/step - loss: 0.2095 - accuracy: 0.9966 - val_loss: 0.2813 - val_accuracy: 0.9683 - lr: 1.0000e-04
# Epoch 27/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9946
# Epoch 27: val_accuracy did not improve from 0.97959
# 64/64 [==============================] - 12s 182ms/step - loss: 0.1983 - accuracy: 0.9946 - val_loss: 0.2463 - val_accuracy: 0.9773 - lr: 1.0000e-04
# Epoch 28/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1869 - accuracy: 0.9917
# Epoch 28: val_accuracy improved from 0.97959 to 0.98073, saving model to best_model.h5
# 64/64 [==============================] - 12s 190ms/step - loss: 0.1869 - accuracy: 0.9917 - val_loss: 0.2285 - val_accuracy: 0.9807 - lr: 1.0000e-04
# Epoch 29/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.9878
# Epoch 29: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 11s 171ms/step - loss: 0.1772 - accuracy: 0.9878 - val_loss: 0.2120 - val_accuracy: 0.9796 - lr: 1.0000e-04
# Epoch 30/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9961
# Epoch 30: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 12s 180ms/step - loss: 0.1470 - accuracy: 0.9961 - val_loss: 0.2058 - val_accuracy: 0.9785 - lr: 1.0000e-04
# Epoch 31/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 12s 180ms/step - loss: 0.1266 - accuracy: 1.0000 - val_loss: 0.1872 - val_accuracy: 0.9807 - lr: 1.0000e-04
# Epoch 32/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.9985
# Epoch 32: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 11s 178ms/step - loss: 0.1199 - accuracy: 0.9985 - val_loss: 0.1802 - val_accuracy: 0.9773 - lr: 1.0000e-04
# Epoch 33/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9932
# Epoch 33: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 10s 156ms/step - loss: 0.1167 - accuracy: 0.9932 - val_loss: 0.1822 - val_accuracy: 0.9717 - lr: 1.0000e-04
# Epoch 34/50
# 65/64 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9927
# Epoch 34: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 11s 174ms/step - loss: 0.1067 - accuracy: 0.9927 - val_loss: 0.1707 - val_accuracy: 0.9717 - lr: 1.0000e-04
# Epoch 35/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9976
# Epoch 35: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 12s 182ms/step - loss: 0.0927 - accuracy: 0.9976 - val_loss: 0.1471 - val_accuracy: 0.9796 - lr: 1.0000e-04
# Epoch 36/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0888 - accuracy: 0.9956
# Epoch 36: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 11s 169ms/step - loss: 0.0888 - accuracy: 0.9956 - val_loss: 0.1418 - val_accuracy: 0.9796 - lr: 1.0000e-04
# Epoch 37/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9946
# Epoch 37: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 10s 156ms/step - loss: 0.0828 - accuracy: 0.9946 - val_loss: 0.1886 - val_accuracy: 0.9626 - lr: 1.0000e-04
# Epoch 38/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9976
# Epoch 38: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 12s 183ms/step - loss: 0.0715 - accuracy: 0.9976 - val_loss: 0.1402 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 39/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9951
# Epoch 39: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 12s 179ms/step - loss: 0.0686 - accuracy: 0.9951 - val_loss: 0.1508 - val_accuracy: 0.9728 - lr: 1.0000e-04
# Epoch 40/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9927
# Epoch 40: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 12s 179ms/step - loss: 0.0714 - accuracy: 0.9927 - val_loss: 0.1174 - val_accuracy: 0.9751 - lr: 1.0000e-04
# Epoch 41/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9966
# Epoch 41: val_accuracy did not improve from 0.98073
# 64/64 [==============================] - 11s 176ms/step - loss: 0.0574 - accuracy: 0.9966 - val_loss: 0.1157 - val_accuracy: 0.9796 - lr: 1.0000e-04
# Epoch 42/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9971
# Epoch 42: val_accuracy improved from 0.98073 to 0.98186, saving model to best_model.h5
# 64/64 [==============================] - 12s 181ms/step - loss: 0.0537 - accuracy: 0.9971 - val_loss: 0.1107 - val_accuracy: 0.9819 - lr: 1.0000e-04
# Epoch 43/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0481 - accuracy: 0.9981
# Epoch 43: val_accuracy did not improve from 0.98186
# 64/64 [==============================] - 12s 181ms/step - loss: 0.0481 - accuracy: 0.9981 - val_loss: 0.1028 - val_accuracy: 0.9785 - lr: 1.0000e-04
# Epoch 44/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9976
# Epoch 44: val_accuracy did not improve from 0.98186
# 64/64 [==============================] - 11s 177ms/step - loss: 0.0435 - accuracy: 0.9976 - val_loss: 0.1161 - val_accuracy: 0.9762 - lr: 1.0000e-04
# Epoch 45/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9976
# Epoch 45: val_accuracy did not improve from 0.98186
# 64/64 [==============================] - 12s 180ms/step - loss: 0.0409 - accuracy: 0.9976 - val_loss: 0.1068 - val_accuracy: 0.9773 - lr: 1.0000e-04
# Epoch 46/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0433 - accuracy: 0.9961
# Epoch 46: val_accuracy did not improve from 0.98186
# 64/64 [==============================] - 12s 180ms/step - loss: 0.0433 - accuracy: 0.9961 - val_loss: 0.0998 - val_accuracy: 0.9785 - lr: 1.0000e-04
# Epoch 47/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 1.0000
# Epoch 47: val_accuracy improved from 0.98186 to 0.98413, saving model to best_model.h5
# 64/64 [==============================] - 12s 191ms/step - loss: 0.0335 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 0.9841 - lr: 1.0000e-04
# Epoch 48/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9971
# Epoch 48: val_accuracy did not improve from 0.98413
# 64/64 [==============================] - 11s 177ms/step - loss: 0.0355 - accuracy: 0.9971 - val_loss: 0.1175 - val_accuracy: 0.9683 - lr: 1.0000e-04
# Epoch 49/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 0.9917
# Epoch 49: val_accuracy did not improve from 0.98413
# 64/64 [==============================] - 11s 178ms/step - loss: 0.0450 - accuracy: 0.9917 - val_loss: 0.0962 - val_accuracy: 0.9807 - lr: 1.0000e-04
# Epoch 50/50
# 65/64 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9937
# Epoch 50: val_accuracy did not improve from 0.98413
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 64/64 [==============================] - 11s 174ms/step - loss: 0.0409 - accuracy: 0.9937 - val_loss: 0.0961 - val_accuracy: 0.9751 - lr: 1.0000e-04
# 28/28 [==============================] - 1s 43ms/step - loss: 0.0961 - accuracy: 0.9751
# Test Setinde Model Doğruluğu: 97.51%
# 28/28 [==============================] - 4s 43ms/step
# Kesinlik: 0.99
# Hatırlama: 0.96
# F1 Skoru: 0.97
